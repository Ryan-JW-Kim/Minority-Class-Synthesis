# %%
import os

s = {}
for file in os.listdir(""):
	with open(file, 'r') as fh:
		for line in fh.readlines():
			key = line.strip().lower()

			if key in s:
				s[key].append(file)
			else:
				s[key] = [file]
s
# Out:
# {'abalone': ['p1.txt'],
#  'anneal': ['p1.txt'],
#  'audiology': ['p1.txt'],
#  'autos': ['p1.txt'],
#  'balance': ['p1.txt', 'p4.txt'],
#  'breast-cancer': ['p1.txt'],
#  'cancer': ['p1.txt'],
#  'card': ['p1.txt'],
#  'dermatology': ['p1.txt'],
#  'ecoli': ['p1.txt'],
#  'gene': ['p1.txt'],
#  'german': ['p1.txt'],
#  'glass': ['p1.txt'],
#  'glass-g2': ['p1.txt'],
#  'heart': ['p1.txt'],
#  'heart-c': ['p1.txt'],
#  'hepatitis': ['p1.txt'],
#  'horse': ['p1.txt'],
#  'hypothyroid': ['p1.txt'],
#  'ionosphere': ['p1.txt'],
#  'iris': ['p1.txt'],
#  'kr vs. kp': ['p1.txt'],
#  'labor': ['p1.txt'],
#  'led24': ['p1.txt'],
#  'liver': ['p1.txt'],
#  'lrs': ['p1.txt'],
#  'lymphography': ['p1.txt'],
#  'new-thyroid': ['p1.txt'],
#  'optdigits': ['p1.txt'],
#  'page-blocks': ['p1.txt', 'p3.txt'],
#  'pendigits': ['p1.txt'],
#  'phoneme': ['p1.txt', 'p3.txt'],
#  'pima': ['p1.txt', 'p4.txt'],
#  'post-operative': ['p1.txt'],
#  'primary-tumor': ['p1.txt'],
#  'promoters': ['p1.txt'],
# ...

# %%
import csv
import os
import pandas as pd

p = "../literature_review_results_extract"
t1 = pd.read_csv(os.path.join(p, "paper_1_error.csv"))
# t2 = pd.read_csv(os.path.join(p, "paper_1_reduction.csv"))
# t3 = pd.read_csv(os.path.join(p, "paper_3_error.csv"))
# t4 = pd.read_csv(os.path.join(p, "paper_4_acc.csv"))


header = [
	"Dataset",
	"Over Sample?",
	"Biased Initialization?",
	"Optimization",
	"Baseline Test Accuracy",
	"Baseline IR",
	"Optimized Test Accuracy",
	"Optimized IR",
	"Reduction Rate %",
	"Optimized Test Acc Diff"
]
    
print(t1)
# print("")
# print(t2)
# print("")
# print(t3)
# print("")
# print(t4)
# Out:
#     Dataset Optimization     Acc Reduction
# 0   phoneme          IB3  0.7035    0.1533
# 1   phoneme        DROP3  0.7733    0.1983
# 2   phoneme          ICF  0.7378    0.1229
# 3   phoneme       GA_CHC  0.7439    0.3142
# 4   phoneme         CCIS  0.7376    0.3293
# 5   phoneme          GBA  0.8283    0.1229
# 6   phoneme         1_NN  0.9048       N/a
# 7      pima          IB3  0.6118    0.1789
# 8      pima        DROP3  0.6737    0.2552
# 9      pima          ICF  0.6513    0.1406
# 10     pima       GA_CHC  0.6408     0.103
# 11     pima         CCIS  0.6961    0.0173
# 12     pima          GBA  0.6927    0.0173
# 13     pima         1_NN  0.6987       N/a
# 14    magic     standard  0.8427       N/a
# 15    magic   stratified  0.8477       N/a
# 16    magic     balanced  0.8492       N/a
# 17  phoneme     standard  0.8352       N/a
# 18  phoneme   stratified  0.8323       N/a
# 19  phoneme     balanced  0.8312       N/a
# 20    magic     LRIS_KNN  0.8192       N/a
# ...
